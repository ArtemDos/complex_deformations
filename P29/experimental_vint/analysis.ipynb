# %%
from core.reader import load_and_filter_ansys_csv

from core.reader import load_and_filter_ansys_csv2

data_file = r'D:\Users\complex_deformations\P29\experimental_vint\bkin.csv'
data_filtered = load_and_filter_ansys_csv2(data_file, time_step=0.1)
print(data_filtered['Time'])
# Out:
# Загрузка файла 'bkin.csv'...
# Исходное количество строк: 1219141
# Файл успешно отфильтрован. Итоговое количество строк: 1051
# 0         0.0
# 1         0.1
# 2         0.2
# 3         0.3
# 4         0.4
#         ...
# 1046    104.6
# 1047    104.7
# 1048    104.8
# 1049    104.9
# 1050    105.0
# Name: Time, Length: 1051, dtype: float64
