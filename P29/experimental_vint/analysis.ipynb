# %%
from core.reader import load_and_filter_ansys_csv
from core.reader import load_experimental_data


numerical_experiment_data = r'D:\Users\complex_deformations\P29\experimental_vint\bkin.csv'
numerical_experiment = load_and_filter_ansys_csv(numerical_experiment_data, time_step=0.1)

real_experiment_data_folder = r'D:\Users\complex_deformations\P29\experimental_vint'
real_experiment = load_experimental_data(real_experiment_data_folder)
# Out:
#      EPTO_TZ   Time
# 0    0.00000    0.0
# 1    0.00000    1.0
# 2    0.00000    2.0
# 3    0.00000    3.0
# 4    0.00000    4.0
# ..       ...    ...
# 100 -0.00215  100.0
# 101 -0.00214  101.0
# 102 -0.00208  102.0
# 103 -0.00193  103.0
# 104 -0.00175  104.0
#
# [105 rows x 2 columns]

# %%
from core.reader import load_experimental_data


real_experiment_data_folder = r'D:\Users\complex_deformations\P29\experimental_vint'
real_experiment = load_experimental_data(real_experiment_data_folder)
print(real_experiment[['EPTO_TZ', 'Time']])
# Out:
#      EPTO_TZ   Time
# 0    0.00000    1.0
# 1    0.00000    2.0
# 2    0.00000    3.0
# 3    0.00000    4.0
# 4    0.00000    5.0
# ..       ...    ...
# 99  -0.00215  100.0
# 100 -0.00214  101.0
# 101 -0.00208  102.0
# 102 -0.00193  103.0
# 103 -0.00175  104.0
#
# [104 rows x 2 columns]

# %%
from core.visualizer import plot_deformation_comparison

plot_deformation_comparison(numerical_experiment, real_experiment)
# Out:
# Данные для визуализации корректны. Начинаем построение графиков...
# График построен.
