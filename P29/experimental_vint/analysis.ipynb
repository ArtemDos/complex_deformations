# %%
from core.reader import load_experimental_data
from core.calculations import calculate_von_mises_stress


real_experiment_data_folder = r'D:\Users\complex_deformations\P29\experimental_vint'
real_experiment = load_experimental_data(real_experiment_data_folder)
real_experiment = calculate_von_mises_stress(
            real_experiment,
            s_x_col='S_TT',
            s_y_col='S_ZZ',
            s_xy_col='S_TZ',
            new_col_name='S_EQV'
        )

# %%
from core.reader import load_and_filter_ansys_csv


numerical_experiment_data_bkin = r'D:\Users\complex_deformations\P29\experimental_vint\bkin.csv'
numerical_experiment_bkin = load_and_filter_ansys_csv(numerical_experiment_data_bkin, time_step=0.1)

# %%
from core.visualizer import plot_xy


model_name = 'BKIN'
plot_xy([
        (model_name, numerical_experiment_bkin)
    ],
    'Time',
    ['EPTO_ZZ', 'EPTO_TT', 'EPTO_TZ'],
    f'Сравнение расчетных (модель {model_name}) и экспериментальных деформаций от времени',
    ('Экперимент', real_experiment)
)

plot_xy([
        (model_name, numerical_experiment_bkin)
    ],
    'Time',
    ['S_ZZ', 'S_TT', 'S_TZ'],
    f'Сравнение расчетных (модель {model_name}) и экспериментальных напряжений от времени',
    ('Экперимент', real_experiment)
)

plot_xy([
        (model_name, numerical_experiment_bkin)
    ],
    'Time',
    ['S_EQV'],
    f'Сравнение расчетных (модель {model_name}) и экспериментальных интенсивностей напряжений от времени',
    ('Экперимент', real_experiment)
)

# %%
numerical_experiment_data_biso = r'D:\Users\complex_deformations\P29\experimental_vint\biso.csv'
numerical_experiment_biso = load_and_filter_ansys_csv(numerical_experiment_data_biso, time_step=0.1)

# %%
model_name = 'BISO'
plot_xy([
        (model_name, numerical_experiment_biso)
    ],
    'Time',
    ['EPTO_ZZ', 'EPTO_TT', 'EPTO_TZ'],
    f'Сравнение расчетных (модель {model_name}) и экспериментальных деформаций от времени',
    ('Экперимент', real_experiment)
)

plot_xy([
        (model_name, numerical_experiment_biso)
    ],
    'Time',
    ['S_ZZ', 'S_TT', 'S_TZ'],
    f'Сравнение расчетных (модель {model_name}) и экспериментальных напряжений от времени',
    ('Экперимент', real_experiment)
)

plot_xy([
        (model_name, numerical_experiment_biso)
    ],
    'Time',
    ['S_EQV'],
    f'Сравнение расчетных (модель {model_name}) и экспериментальных интенсивностей напряжений от времени',
    ('Экперимент', real_experiment)
)

# %%
numerical_experiment_data_chab = r'D:\Users\complex_deformations\P29\experimental_vint\chab.csv'
numerical_experiment_chab = load_and_filter_ansys_csv(numerical_experiment_data_chab, time_step=0.1)

# %%
model_name = 'CHAB'
plot_xy([
        (model_name, numerical_experiment_chab)
    ],
    'Time',
    ['EPTO_ZZ', 'EPTO_TT', 'EPTO_TZ'],
    f'Сравнение расчетных (модель {model_name}) и экспериментальных деформаций от времени',
    ('Экперимент', real_experiment)
)

plot_xy([
        (model_name, numerical_experiment_chab)
    ],
    'Time',
    ['S_ZZ', 'S_TT', 'S_TZ'],
    f'Сравнение расчетных (модель {model_name}) и экспериментальных напряжений от времени',
    ('Экперимент', real_experiment)
)

plot_xy([
        (model_name, numerical_experiment_chab)
    ],
    'Time',
    ['S_EQV'],
    f'Сравнение расчетных (модель {model_name}) и экспериментальных интенсивностей напряжений от времени',
    ('Экперимент', real_experiment)
)

# %%
plot_xy([
        ('BKIN', numerical_experiment_bkin),
        ('BISO', numerical_experiment_biso),
        ('CHAB', numerical_experiment_chab)
    ],
    'Time',
    'S_ZZ',
    f'Сравнение расчетных (модели BKIN, BISO, CHAB) и экспериментальных напряжений S_ZZ от времени',
    ('Экперимент', real_experiment)
)

plot_xy([
        ('BKIN', numerical_experiment_bkin),
        ('BISO', numerical_experiment_biso),
        ('CHAB', numerical_experiment_chab)
    ],
    'Time',
    'S_TT',
    f'Сравнение расчетных (модели BKIN, BISO, CHAB) и экспериментальных напряжений S_TT от времени',
    ('Экперимент', real_experiment)
)

plot_xy([
        ('BKIN', numerical_experiment_bkin),
        ('BISO', numerical_experiment_biso),
        ('CHAB', numerical_experiment_chab)
    ],
    'Time',
    'S_TZ',
    f'Сравнение расчетных (модели BKIN, BISO, CHAB) и экспериментальных напряжений S_TZ от времени',
    ('Экперимент', real_experiment)
)

plot_xy([
        ('BKIN', numerical_experiment_bkin),
        ('BISO', numerical_experiment_biso),
        ('CHAB', numerical_experiment_chab)
    ],
    'Time',
    ['S_EQV'],
    f'Сравнение расчетных (модели BKIN, BISO, CHAB) и экспериментальных интенсивностей напряжений от времени',
    ('Экперимент', real_experiment)
)
